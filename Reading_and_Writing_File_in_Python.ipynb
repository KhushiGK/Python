# %%
with open('file.txt','r') as file:
  file_stuff=file.read()
  print(file_stuff)
# Out:
# Strong in design and integration with intuitive problem-solving skills.
# Proficient in PYTHON, SQL, EXCEL, TABLEAU, POWER BI, IBM Cognos Analytics, Data Analytics, Data Visualization, Frontend.
# Passionate about implementing and launching new projects.
# Skilled in problem-solving and analytical thinking. Ability to translate business requirements into technical solutions.
# Seeking a beginner role to enhance and explore my technical knowledge gained in the last 4 years.

# %%
file=open('file.txt','r')

# %%
line1=file.readline()
line2=file.readline()

# %%
print(line1)
if 'important' in line2:
  print('This line is important!')
# Out:
# Strong in design and integration with intuitive problem-solving skills.

# %%
while True:
  line=file.readline()
  if not line:
    break
  print(line)
# Out:
# Passionate about implementing and launching new projects.
#
# Skilled in problem-solving and analytical thinking. Ability to translate business requirements into technical solutions.
#
# Seeking a beginner role to enhance and explore my technical knowledge gained in the last 4 years.

# %%
file.close()

# %%
file=open('file.txt','r')
file.seek(10)
# Out:
# 10

# %%
characters=file.read(5)
print(characters)
# Out:
# desig

# %%
file.close()

# %%
## Uncomment these if working locally, else let the following code cell run.

import urllib.request
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt'
filename = 'Example1.txt'
urllib.request.urlretrieve(url, filename)

## Download Example file
# !wget Example1.txt https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt
# Out:
# --2024-06-15 09:21:10--  http://example1.txt/
# Resolving example1.txt (example1.txt)... failed: Name or service not known.
# wget: unable to resolve host address ‘example1.txt’
# --2024-06-15 09:21:10--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘example1.txt’
#
# example1.txt        100%[===================>]      45  --.-KB/s    in 0s
#
# 2024-06-15 09:21:10 (14.1 MB/s) - ‘example1.txt’ saved [45/45]
#
# FINISHED --2024-06-15 09:21:10--
# Total wall clock time: 0.07s
# ...

# %%
example1='example1.txt'
file1=open(example1,'r')

# %%
file1.name
# Out:
# 'example1.txt'

# %%
file1.mode
# Out:
# 'r'

# %%
fileContent=file1.read()
fileContent
# Out:
# 'This is line 1 \nThis is line 2\nThis is line 3'

# %%
print(fileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
type(fileContent)
# Out:
# str

# %%
file1.close()

# %%
with open(example1,'r') as file1:
  fileContent=file1.read()
  print(fileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
file1.close()

# %%
print(fileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
#read the first 4 chars
with open(example1,'r') as file1:
  print(file1.read(4))
# Out:
# This

# %%
with open(example1,'r') as file1:
  print('First line: '+file1.readline())
# Out:
# First line: This is line 1

# %%
with open(example1,'r') as file1:
  i=0
  for line in file1:
    print('iteration',str(i),': ',line)
    i=i+1
# Out:
# iteration 0 :  This is line 1
#
# iteration 1 :  This is line 2
#
# iteration 2 :  This is line 3

# %%
with open(example1,'r') as file1:
  Fileaslist=file1.readlines()

# %%
print(Fileaslist[0])
# Out:
# This is line 1

# %%
example2='Example2.txt'
with open(example2,'w') as writefile:
  writefile.write('This is line A')

# %%
with open(example2,'r') as testwritefile:
  print(testwritefile.read())
# Out:
# This is line A

# %%
with open(example2,'w') as writefile:
  writefile.write('This is line A/n')
  writefile.write('This is line B/n')

# %%
with open(example2,'r') as testwritefile:
  print(testwritefile.read())
# Out:
# This is line A/nThis is line B/n

# %%
Lines=['This is line A', 'This is line B', 'This is line C']

# %%
with open('Example2.txt','w') as writefile:
  for line in Lines:
    print(line)
    writefile.write(line+'\n')
# Out:
# This is line A
# This is line B
# This is line C

# %%
with open('Example2.txt','r') as testwritefile:
  print(testwritefile.read())
# Out:
# This is line A
# This is line B
# This is line C

# %%
with open('Example2.txt','w') as writefile:
  writefile.write('Overwrite\n')
with open('Example2.txt','r') as testwritefile:
  print(testwritefile.read())
# Out:
# Overwrite

# %%
with open('Example2.txt','a') as testwritefiles:
  testwritefiles.write('This is line C\n')
  testwritefiles.write('This is line D\n')
  testwritefiles.write('This is line E\n')

# %%
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite
# This is line C
# This is line D
# This is line E

# %%
with open('Example2.txt','a+') as testwritefile:
  testwritefile.write('This is line E\n')
  print(testwritefile.read())

# %%
with open('Example.txt','a+') as testwritefile:
  print('Initial Location: {}'.format(testwritefile.tell()))

  data=testwritefile.read()
  if (not data):
    print('Read nothing')

  else:
    print(testwritefile.read())

  testwritefile.seek(0,0)

  print('\nNew Location: {}'.format(testwritefile.tell()))
  data=testwritefile.read()
  if (not data):
    print('Read nothing')
  else:
    print(data)
  print('location after read: {}'.format(testwritefile.tell()))
# Out:
# Initial Location: 0
# Read nothing
#
# New Location: 0
# Read nothing
# location after read: 0

# %%
with open('Example2.txt', 'r+') as testwritefile:
    testwritefile.seek(0,0) #write at beginning of file
    testwritefile.write("Line 1" + "\n")
    testwritefile.write("Line 2" + "\n")
    testwritefile.write("Line 3" + "\n")
    testwritefile.write("Line 4" + "\n")
    testwritefile.write("finished\n")
    testwritefile.seek(0,0)
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4
# finished
#  D
# This is line E
# This is line E
# This is line E

# %%
with open('Example2.txt', 'r+') as testwritefile:
    testwritefile.seek(0,0) #write at beginning of file
    testwritefile.write("Line 1" + "\n")
    testwritefile.write("Line 2" + "\n")
    testwritefile.write("Line 3" + "\n")
    testwritefile.write("Line 4" + "\n")
    testwritefile.write("finished\n")
    #Uncomment the line below
    testwritefile.truncate()
    testwritefile.seek(0,0)
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4
# finished

# %%
#copy a file
with open('Example2.txt','r') as readfile:
  with open('Example3.txt','w') as writefile:
    for line in readfile:
      writefile.write(line)

# %%
with open('Example3.txt','r') as testwritefile:
  print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# Line 4
# finished

# %%
from random import randint as rnd

memreg='members.txt'
exReg='incative.txt'
fee=('yes','no')

def genFiles(current,old):
  with open(current,'w+') as writefile:
    writefile.write('Membership No  Data Joined Active  \n')
    data='{:^13} {:<11} {:<6}\n'

    for rowno in range(20):
      date = str(rnd(2015,2020))+'-'+str(rnd(1,12))+'-'+str(rnd(1,25))
      writefile.write(data.format(rnd(10000,99999),date,free[rnd(0,1)]))


    with open(old,'w+') as writefile:
      writefile.write('Membership No  date Joined  Active  \n')
      data='{:^13} {:<11} {:<6}\n'
      for rowno in range(3):
        date = str(rnd(2015,2020))+'-'+str(rnd(1,12))+'-'+str(rnd(1,25))
        writefile.write(data.format(rnd(10000,99999),date,free[rnd(0,1)]))

# %%
import pandas as pd

data=[10,20,30,40,50]
s=pd.Series(data)
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(s[2])
# Out:
# 30

# %%
print(s.iloc[3])
# Out:
# 40

# %%
data={'Name':['Alice', 'Bob', 'Charlie', 'David'],
      'Age':[25, 30, 35, 28],
      'City':['New York', 'San Fransisco', 'Los Angeles', 'Chicago']}

df=pd.DataFrame(data)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Fransisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object

# %%
print(df.iloc[2])
print(df.loc[1])
# Out:
# Name        Charlie
# Age              35
# City    Los Angeles
# Name: 2, dtype: object
# Name              Bob
# Age                30
# City    San Fransisco
# Name: 1, dtype: object

# %%
print(df[['Name','Age']])
print()
print(df[1:3])
# Out:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   28
#
#       Name  Age           City
# 1      Bob   30  San Fransisco
# 2  Charlie   35    Los Angeles

# %%
unique_dates=df['Age'].unique()
unique_dates
# Out:
# array([25, 30, 35, 28])

# %%
high_above_102=df[df['Age']>25]
high_above_102
# Out:
#       Name  Age           City
# 1      Bob   30  San Fransisco
# 2  Charlie   35    Los Angeles
# 3    David   28        Chicago

# %%
df.to_csv('trading_data.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   29.500000
# std     4.203173
# min    25.000000
# 25%    27.250000
# 50%    29.000000
# 75%    31.250000
# max    35.000000

# %%
mean_col=df['Age'].mean()
print(mean_col)
# Out:
# 29.5

# %%
df['Age'].max()
# Out:
# 35

# %%
df.sort_values('Age')
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 3    David   28        Chicago
# 1      Bob   30  San Fransisco
# 2  Charlie   35    Los Angeles

# %%
x = {'Name': ['Rose','John', 'Jane', 'Mary'], 'ID': [1, 2, 3, 4], 'Department': ['Architect Group', 'Software Group', 'Design Team', 'Infrastructure'],
      'Salary':[100000, 80000, 50000, 60000]}
df=pd.DataFrame(x)
df
# Out:
#    Name  ID       Department  Salary
# 0  Rose   1  Architect Group  100000
# 1  John   2   Software Group   80000
# 2  Jane   3      Design Team   50000
# 3  Mary   4   Infrastructure   60000

# %%
x=df[['ID']]
x
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 3   4

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
# Access to multiple columns
z=df[['Department','Salary','ID']]
z
# Out:
#         Department  Salary  ID
# 0  Architect Group  100000   1
# 1   Software Group   80000   2
# 2      Design Team   50000   3
# 3   Infrastructure   60000   4

# %%
std_marks={'Student':['David', 'Samule', 'Terry', 'Evan'],
           'Age':[27, 24, 22, 32],
           'Country':['UK','Canada','China','USA'],
           'Course':['Python', 'Data Structures', 'Machine Learning', 'Web Development'],
           'Marks': [85, 72, 89, 76]}

df=pd.DataFrame(std_marks)
df
# Out:
#   Student  Age Country            Course  Marks
# 0   David   27      UK            Python     85
# 1  Samule   24  Canada   Data Structures     72
# 2   Terry   22   China  Machine Learning     89
# 3    Evan   32     USA   Web Development     76

# %%
# Problem 2: Retrieve the Marks column and assign it to a variable b
b=df[['Marks']]
b
# Out:
#    Marks
# 0     85
# 1     72
# 2     89
# 3     76

# %%
# Problem 3: Retrieve the Country and Course columns and assign it to a variable c
c=df[['Country', 'Course']]
c
# Out:
#   Country            Course
# 0      UK            Python
# 1  Canada   Data Structures
# 2   China  Machine Learning
# 3     USA   Web Development

# %%
x=df['Student']
x
# Out:
# 0     David
# 1    Samule
# 2     Terry
# 3      Evan
# Name: Student, dtype: object

# %%
type(x)
# Out:
# pandas.core.series.Series

# %% [markdown]
# loc()- lable-based data - we have to
# pass the name of the row or column
#
# iloc()- index-based- pass and integer

# %%
df.iloc[0,0] #first row and first col
# Out:
# 'David'

# %%
df.iloc[0,2] #first row & 3rd col
# Out:
# 'UK'

# %%
df.loc[0, 'Marks']
# Out:
# 85

# %%
df1=pd.DataFrame(x)
df1
# Out:
#   Student
# 0   David
# 1  Samule
# 2   Terry
# 3    Evan
